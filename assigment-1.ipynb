# %% [markdown]
#                                             ASSIGNMENT-1
#
# Q1-   Who developed python programming language?
#
# Ans-  Python programming language developed by Guido van Rossam.He started working on python December 1989,and           first version of python is released in february 1991.python was named after monty python,a british comedy         group.
#
#
# Q2-   Which type of programming does python support?
#
# Ans-  Python support multiple programmig paradigms-
#       object oriented programming - This aloow the certain of objects and classes.
#       Imperative programming      - This involeve using statement to specify the sequance of action
#       Fuctional programming       - This involeve treating computation as the evalution of mathmatical fuction.
#       Procedural programming      - This involeve breaking down a problem
#
#
# Q3-   Is pyhon case sensitive when dealing with identifiers?
#
# Ans-  Yes, python is case sensitive when dealing with identifiers,such as variable names , class names , fuction         names.
#
#
# Q4-   What is the correct extention of python file?
#
# Ans-  The correct extention of python is .py
#
#
# Q5-   Is python code compiled or interpreted?
# Ana-  python is a interpretesd language not a compiled language.
#
#
# Q6-   Name a few blocks of code used to define in python language?
#
# Ans-  Identation is used to blocks of code used to define in python language.
#
#
# Q7-   State a character used to give single line comments in python?
#
# Ans-  used (#) character to give single line comments in python.
#
#
# Q8-   Mention fuction which can help us to find the version of python that we are currently working on?
#
# Ans-  sys. version
#
#
# Q9-   Python supports the creation of anonymous fuctions at runtime, using a construct called ?
#
# Ans-  lambda
#
#
# Q10-  What does pip stand for python ?
#
# Ans-  Pip installs packages.
#
#
# Q11-  Mention a few built-in fuctions in python?
#
# Ans-  few built-in fuction in python-
#       input()
#       print()
#       len()
#       list()
#       range()
#
#
# Q12-  What is the maximum possible length of an identifier in python?
#
# Ans-  79 characters .
#
#
# Q13-  What is the benefits of using python?
#
# Ans-  Many benefits of using python -
#       1- Versatile
#          Python can be used for a wide range of applications,including -web development,scientific computing data,
#          data analysis,artificial inteligence .
#       2- Good For prototyping
#       3- Large community
#       4- Easy to lern and use
#
#
# Q-14   How is memory managed in python ?
#
# Ans-   Python uses automatic memory management , which means the python memory manager automatically handles              memory  allocaton and deallocaton.
#
#
# Q15    How to install Python on windows and set path variables ?
#
# Ans-   1- Download the latest version of python from the official website.
#        2- Run the installer and follow the instruction to install in system.
#        3- Add python to inviremental variables.
#        4- Verify the python installation
#
# set A path
#        5- Right clicking this PC and going to properties
#        6- Clicking on the advanced system
#        7- In the system variable section,selecting the path variable and clicking on edit.
#
#
# Q16-   Is indentation required in python ?
#
#
# Ans-   Yes, indentation is required in python. indentation is used to indicate the block of code associated with          control structures such as loop and condition statements.
